# %%
mystr = "Keep On Truckin"

# %%
mystr=mystr.upper()

# %%
mystr
# Out:
# 'KEEP ON TRUCKIN'

# %%
mystr.lower()
# Out:
# 'keep on truckin'

# %%
mystr.startswith('K')
# Out:
# True

# %%
mystr.find('On')
# Out:
# 5

# %%
'ON' in mystr # member ship validation
# Out:
# True

# %% [markdown]
# Not So frequently used methods.

# %%
mystr.casefold() # returns string for caseless comparison
# Out:
# 'keep on truckin'

# %%
mystr.endswith('n',5,7)
# Out:
# True

# %%
mystr.index('On')
# Out:
# 5

# %%
mystr.lower().rindex('k')
# Out:
# 12

# %%
mystr.lower().index('k')
# Out:
# 0

# %%
r'\tstr\t'.expandtabs()
# Out:
# '\\tstr\\t'

# %%
mystr.
